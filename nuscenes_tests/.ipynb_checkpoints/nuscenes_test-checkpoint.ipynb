# %%
# %pip install matplotlib

# %%
# %pip install pyarrow

# %%
import os

import numpy
import pandas
import matplotlib.pyplot as plt

from PIL import Image

# %% [markdown]
# ## Constants and Setup

# %%
# %matplotlib inline

# %%
PREFIX = '../data/nuscenes/samples/CAM_FRONT'

# %%
INDEX = 5

# %%
images = os.listdir(PREFIX)

# %%
WIDTH = 500
HEIGHT = 450

# %% [markdown]
# ## Testing

# %%
test_image = os.path.join(PREFIX, images[INDEX])

# %%
im = Image.open(test_image)

# %%
# im.show()

'''
Unable to init server: Could not connect: Connection refused

(eog:45725): Gtk-WARNING **: 12:30:38.940: cannot open display: 
'''
# Out:
# '\nUnable to init server: Could not connect: Connection refused\n\n(eog:45725): Gtk-WARNING **: 12:30:38.940: cannot open display: \n'

# %%
from IPython.display import Image, display

display(Image(filename=test_image, width=WIDTH, height=HEIGHT))
